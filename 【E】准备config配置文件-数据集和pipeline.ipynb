# %% [markdown]
# # 准备config配置文件-数据集和pipeline
#
# 2025-4-30

# %% [markdown]
# ## 进入MMSegmentation主目录

# %%
import os
os.chdir('mmsegmentation')

# %%
os.getcwd()
# Out:
# '/home/featurize/work/mmsegmentation'

# %% [markdown]
# ## 一：数据集配置文件
#
# 定义数据集类（各类别名称及配色）我这里是自己定义的窗户数据

# %%
# !rm -rf mmseg/datasets/windowcolor.py # 删除原有文件
# 从阿里云OSS下载
# !wget https://windowsdataset.oss-cn-shenzhen.aliyuncs.com/windowcolor.py -P mmseg/datasets
# Out:
# --2025-04-30 12:57:14--  https://windowsdataset.oss-cn-shenzhen.aliyuncs.com/windowcolor.py
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 743 [application/octet-stream]
# 正在保存至: “mmseg/datasets/windowcolor.py”
#
# windowcolor.py      100%[===================>]     743  --.-KB/s    用时 0s
#
# 2025-04-30 12:57:14 (147 MB/s) - 已保存 “mmseg/datasets/windowcolor.py” [743/743])

# %% [markdown]
# ## 二：注册数据集类
#
# 在`mmseg/datasets/__init__.py`中注册刚刚定义的`windowcolor`数据集类 可以直接手动去修改，一定要记得改三个地方啊![55b4f5b5a55940fa43fa28fc1cad6da.png](attachment:e1ba1e51-0d78-45b3-a7fa-b33b4451e240.png)

# %% [markdown]
# 这个部分直接在mmseg/datasets/__init__.py中修改会比较快，在上面改完之后，记得下面的大类里面也加入自己设定的配置文件

# %% [markdown]
# ## 三：pipeline配置文件
#
# 数据集路径、预处理、后处理、DataLoader、测试集评估指标

# %%
# 这个地方是下载我自己的winpipeline，类别只分了两类
# !wget https://windowsdataset.oss-cn-shenzhen.aliyuncs.com/winpipeline.py -P configs/_base_/datasets
# Out:
# --2025-04-30 13:06:54--  https://windowsdataset.oss-cn-shenzhen.aliyuncs.com/winpipeline.py
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 2684 (2.6K) [application/octet-stream]
# 正在保存至: “configs/_base_/datasets/winpipeline.py”
#
# winpipeline.py      100%[===================>]   2.62K  --.-KB/s    用时 0s
#
# 2025-04-30 13:06:54 (465 MB/s) - 已保存 “configs/_base_/datasets/winpipeline.py” [2684/2684])
